# %%
import pandas as pd

# %%
df=pd.read_csv('zomatopro.csv')
df
# Out:
#        Unnamed: 0  index                                               name  \
# 0               0      0                                              Jalsa
# 1               1      1                                     Spice Elephant
# 2               2      2                                    San Churro Cafe
# 3               3      3                              Addhuri Udupi Bhojana
# 4               4      4                                      Grand Village
# ...           ...    ...                                                ...
# 27653       27653  30331                         The Farm House Bar n Grill
# 27654       27654  30332                                            Bhagini
# 27655       27655  30333  Best Brews - Four Points by Sheraton Bengaluru...
# 27656       27656  30334  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 27657       27657  30335                       The Nest - The Den Bengaluru
#
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)
df.drop(columns=['index'],inplace=True)

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 27653                         The Farm House Bar n Grill           No
# 27654                                            Bhagini           No
# 27655  Best Brews - Four Points by Sheraton Bengaluru...           No
# 27656  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 27657                       The Nest - The Den Bengaluru           No
#
#       book_table  rating  votes  approx_cost            rest_type  \
# ...

# %%
#rate_mapping = {'Male': 0,'Female':1}
#df.Gender = df.Gender.map(gender_mapping)

# %%
#df

# %%
#ages = df.Age

#min_value = min(ages)
#max_value = max(ages)
#min_range = -1
#max_range = 1

#df.Age = (df.Age - min_value)/(max_value - min_value)*(max_range - min_range) + min_range

# %%
#df

# %%
vote = df['votes']

min_value = min(vote)
max_value = max(vote)
min_range = -1
max_range = 1

df['votes'] = (df['votes'] - min_value)/(max_value - min_value)*(max_range - min_range) + min_range

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 27653                         The Farm House Bar n Grill           No
# 27654                                            Bhagini           No
# 27655  Best Brews - Four Points by Sheraton Bengaluru...           No
# 27656  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 27657                       The Nest - The Den Bengaluru           No
#
#       book_table  rating     votes  approx_cost            rest_type  \
# ...

# %%
rating = df['rating']

min_value = min(rating)
max_value = max(rating)
min_range = -1
max_range = 1

df['rating'] = (df['rating'] - min_value)/(max_value - min_value)*(max_range - min_range) + min_range

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 27653                         The Farm House Bar n Grill           No
# 27654                                            Bhagini           No
# 27655  Best Brews - Four Points by Sheraton Bengaluru...           No
# 27656  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 27657                       The Nest - The Den Bengaluru           No
#
#       book_table    rating     votes  approx_cost            rest_type  \
# ...

# %%
cost = df['approx_cost']

min_value = min(cost)
max_value = max(cost)
min_range = -1
max_range = 1

df['approx_cost'] = (df['approx_cost'] - min_value)/(max_value - min_value)*(max_range - min_range) + min_range

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 27653                         The Farm House Bar n Grill           No
# 27654                                            Bhagini           No
# 27655  Best Brews - Four Points by Sheraton Bengaluru...           No
# 27656  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 27657                       The Nest - The Den Bengaluru           No
#
#       book_table    rating     votes  approx_cost            rest_type  \
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 scaler = MinMaxScaler()
# ----> 2 scaled_data = scaler.fit_transform(df)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:878, in TransformerMixin.fit_transform(self, X, y, **fit_params)
# ...

# %%
wcss = []

k_values = range(1,11)

for k in k_values:
    kmeans=KMeans(n_clusters = k)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Rakesh Agarwal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Rakesh Agarwal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Rakesh Agarwal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(k_values, wcss, marker = 'o')
plt.xlabel('No. of Clusters (K)')
plt.ylabel('Within Cluster Sum Of Squares (WCSS)')
plt.title('Elbow Method')
plt.show()

# %%
kmeans = KMeans(n_clusters = 3)

kmeans.fit(df)

cluster_labels=kmeans.labels_

cluster_centres = scaler.inverse_transform(kmeans.cluster_centers_)

df['cluster'] = cluster_labels

df = df.assign(cluster = cluster_labels)
# Out:
# C:\Users\Rakesh Agarwal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Rakesh Agarwal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
df
# Out:
#      Gender       Age       A/I       S/S  cluster
# 0         0 -0.961538 -1.000000 -0.224490        0
# 1         0 -0.884615 -1.000000  0.632653        0
# 2         1 -0.923077 -0.983607 -0.897959        1
# 3         1 -0.807692 -0.983607  0.551020        0
# 4         1 -0.500000 -0.967213 -0.204082        1
# ..      ...       ...       ...       ...      ...
# 195       1 -0.346154  0.721311  0.591837        0
# 196       1  0.038462  0.819672 -0.448980        1
# 197       0 -0.461538  0.819672  0.489796        0
# 198       0 -0.461538  1.000000 -0.653061        2
# 199       0 -0.538462  1.000000  0.673469        0
#
# [200 rows x 5 columns]

# %%
plt.scatter(df.cluster, df['S/S'])
plt.xlabel('Clusters')
plt.ylabel('Spending Score')
plt.title('K-Means Clustering')
plt.show()

# %%
plt.scatter(df.cluster, df['Age'])
plt.xlabel('Clusters')
plt.ylabel('Age')
plt.title('K-Means Clustering')
plt.show()

# %%
plt.scatter(df.cluster, df['A/I'])
plt.xlabel('Clusters')
plt.ylabel('Annual Income (A/I)')
plt.title('K-Means Clustering')
plt.show()

# %%
plt.scatter(df.cluster, df['Gender'])
plt.xlabel('Clusters')
plt.ylabel('Gender')
plt.title('K-Means Clustering')
plt.show()

# %%
### DBSCAN CLUSTERING

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
df = df.drop('cluster', axis=1)

# %%
df
# Out:
#      Gender       Age       A/I       S/S
# 0         0 -0.961538 -1.000000 -0.224490
# 1         0 -0.884615 -1.000000  0.632653
# 2         1 -0.923077 -0.983607 -0.897959
# 3         1 -0.807692 -0.983607  0.551020
# 4         1 -0.500000 -0.967213 -0.204082
# ..      ...       ...       ...       ...
# 195       1 -0.346154  0.721311  0.591837
# 196       1  0.038462  0.819672 -0.448980
# 197       0 -0.461538  0.819672  0.489796
# 198       0 -0.461538  1.000000 -0.653061
# 199       0 -0.538462  1.000000  0.673469
#
# [200 rows x 4 columns]

# %%
dbscan = DBSCAN(eps = 0.5, min_samples = 5)

# %%
clusters = dbscan.fit_predict(df)

# %%
df['clusters'] = clusters

# %%
df
# Out:
#      Gender       Age       A/I       S/S  clusters
# 0         0 -0.961538 -1.000000 -0.224490        -1
# 1         0 -0.884615 -1.000000  0.632653         0
# 2         1 -0.923077 -0.983607 -0.897959        -1
# 3         1 -0.807692 -0.983607  0.551020         1
# 4         1 -0.500000 -0.967213 -0.204082         1
# ..      ...       ...       ...       ...       ...
# 195       1 -0.346154  0.721311  0.591837         1
# 196       1  0.038462  0.819672 -0.448980         1
# 197       0 -0.461538  0.819672  0.489796         0
# 198       0 -0.461538  1.000000 -0.653061        -1
# 199       0 -0.538462  1.000000  0.673469        -1
#
# [200 rows x 5 columns]

# %%
plt.scatter(df['S/S'], df['A/I'], c = clusters, cmap = 'viridis' )
plt.xlabel('Spending Score(S/S)')
plt.ylabel('Annual Income(A/I)')
plt.title('DBSCAN Clustering')
plt.show()

# %%
plt.scatter(df['S/S'], df['Age'], c = clusters, cmap = 'viridis' )
plt.xlabel('Spending Score(S/S)')
plt.ylabel('Age')
plt.title('DBSCAN Clustering')
plt.show()

# %%
plt.scatter(df['S/S'], df['Gender'], c = clusters, cmap = 'viridis' )
plt.xlabel('Spending Score(S/S)')
plt.ylabel('Gender')
plt.title('DBSCAN Clustering')
plt.show()
